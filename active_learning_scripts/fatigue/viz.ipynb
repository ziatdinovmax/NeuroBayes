# %%
import sys
sys.path.append("..")

from vizutils import plot_comparison

# %% [markdown]
# ## PBNN-8-8-8-8

# %% [markdown]
# ### SILU

# %%
pbnn_files = [
    'results/pbnn8888/fatigue_probdense0-dense4_steps200_epochs2000_lr0.005_20241209_220515.pkl',
    'results/pbnn8888/fatigue_probdense1-dense4_steps200_epochs2000_lr0.005_20241210_061349.pkl',
    'results/pbnn8888/fatigue_probdense2-dense4_steps200_epochs2000_lr0.005_20241210_095911.pkl',
    'results/pbnn8888/fatigue_probdense3-dense4_steps200_epochs2000_lr0.005_20241209_140952.pkl'
]

bnn_file = 'results/bnn8888/fatigue_steps200_20241212_220424.pkl'

plot_comparison(
    pbnn_files=pbnn_files,
    bnn_file=bnn_file,
    mse_symlog=True,
    mse_ylim=(10, 120),
    nlpd_ylim=(4, 18),
    nlpd_symlog=False,
    coverage_symlog=False,
    coverage_ylim=(0.25, 1.05),
    save_path='comparison_plot-pbnn8888-silu.png'
);
# Out:
# Final values (mean ± std):
#
# PBNN (0, 4):
#   RMSE: 16.8148 ± 0.8055
#   NLPD: 4.3112 ± 0.0329
#   COVERAGE: 0.9788 ± 0.0126
#
# PBNN (1, 4):
#   RMSE: 19.6679 ± 1.0744
#   NLPD: 4.4723 ± 0.1066
#   COVERAGE: 0.8977 ± 0.0378
#
# PBNN (2, 4):
#   RMSE: 20.0668 ± 0.9651
#   NLPD: 4.4729 ± 0.0773
#   COVERAGE: 0.8876 ± 0.0225
#
# PBNN (3, 4):
#   RMSE: 20.3224 ± 0.9441
#   NLPD: 4.4777 ± 0.0786
#   COVERAGE: 0.9014 ± 0.0190
#
# Full BNN:
#   RMSE: 17.5652 ± 1.3479
#   NLPD: 4.2702 ± 0.0598
#   COVERAGE: 0.9429 ± 0.0227

# %% [markdown]
# Comparison with DKL:

# %%
pbnn_files = [
    'results/pbnn8888/fatigue_probdense0-dense4_steps200_epochs2000_lr0.005_20241209_220515.pkl'
]

dkl_files = ['results/dkl8888/fatigue_dkl_latent2_silu_20241213_172102.pkl']

plot_comparison(
    pbnn_files=pbnn_files,
    dkl_files=dkl_files,
    save_path='comparison_plot-dkl-pbnn8888-silu.png'
);
# Out:
# Final values (mean ± std):
#
# PBNN (0, 4):
#   RMSE: 16.8148 ± 0.8055
#   NLPD: 4.3112 ± 0.0329
#   COVERAGE: 0.9788 ± 0.0126
#
# DKL (latent=2, silu):
#   RMSE: 25.8603 ± 1.9743
#   NLPD: 5.6189 ± 0.0138
#   COVERAGE: 1.0000 ± 0.0000

# %% [markdown]
# Comparison with GP:

# %%
pbnn_files = [
    'results/pbnn8888/fatigue_probdense0-dense4_steps200_epochs2000_lr0.005_20241209_220515.pkl'
]

gp_files = ['results/gp/fatigue_gp_comparison_kernelmatern52_20241213_170217.pkl']

plot_comparison(
    pbnn_files=pbnn_files,
    gp_files=gp_files,
    save_path='comparison_plot-gp-pbnn8888-silu.png'
);
# Out:
# Final values (mean ± std):
#
# PBNN (0, 4):
#   RMSE: 16.8148 ± 0.8055
#   NLPD: 4.3112 ± 0.0329
#   COVERAGE: 0.9788 ± 0.0126
#
# GP (matern52):
#   RMSE: 17.2251 ± 0.3234
#   NLPD: 4.3329 ± 0.0087
#   COVERAGE: 0.9759 ± 0.0039
