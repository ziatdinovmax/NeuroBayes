# %%
import sys
sys.path.append("..")

from plot_utils import plot_sigma_comparison, plot_pretrain_comparison
from pathlib import Path

# %%
# Set directories
pbnn_dir = Path("results/pbnn321688")
ptpbnn_dir = Path("results/ptpbnn321688")

# %%
# Plot sigma comparison for pre-trained models with custom settings
fig, axes = plot_sigma_comparison(
    ptpbnn_dir,
    figsize=(16, 5),
    nlpd_symlog=True,
    nlpd_ylim=(1, 1000),
    coverage_ylim=(-0.1, 1)
)

# Plot comparison between pre-trained and non-pre-trained models
fig, axes = plot_pretrain_comparison(
    pbnn_dir,
    ptpbnn_dir,
    figsize=(16, 5),
    sigma=1.0,
    nlpd_symlog=True,
    nlpd_ylim=(1, 1000),
    coverage_ylim=(-0.1, 1),
)
