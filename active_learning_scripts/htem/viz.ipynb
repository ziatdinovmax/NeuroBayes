# %%
import sys
sys.path.append("..")

from vizutils import plot_comparison

# %%
pbnn_files = [
    'results/pbnn8888/htem_probdense0-dense4_steps200_epochs2000_lr0.005_20241208_213629.pkl',
    'results/pbnn8888/htem_probdense1-dense4_steps200_epochs2000_lr0.005_20241209_020922.pkl',
    'results/pbnn8888/htem_probdense2-dense4_steps200_epochs2000_lr0.005_20241209_055114.pkl',
    'results/pbnn8888/htem_probdense3-dense4_steps200_epochs2000_lr0.005_20241208_155326.pkl'
]

bnn_file = 'results/bnn8888/htem_steps200_20241213_105942.pkl'

plot_comparison(
    pbnn_files=pbnn_files,
    bnn_file=bnn_file,
    mse_ylim=(0.1, 1.2),
    nlpd_symlog=False,
    coverage_ylim=(0.25, 1.05),
    save_path='comparison_plot-pbnn8888-silu.png'
);
# Out:
# Final values (mean ± std):
#
# PBNN (0, 4):
#   RMSE: 0.2456 ± 0.0258
#   NLPD: 0.1619 ± 0.0292
#   COVERAGE: 0.9823 ± 0.0101
#
# PBNN (1, 4):
#   RMSE: 0.2700 ± 0.0193
#   NLPD: 0.1149 ± 0.0688
#   COVERAGE: 0.9518 ± 0.0122
#
# PBNN (2, 4):
#   RMSE: 0.2995 ± 0.0254
#   NLPD: 0.2910 ± 0.1481
#   COVERAGE: 0.9240 ± 0.0265
#
# PBNN (3, 4):
#   RMSE: 0.3178 ± 0.0309
#   NLPD: 0.5508 ± 0.3754
#   COVERAGE: 0.8691 ± 0.0684
#
# Full BNN:
#   RMSE: 0.1563 ± 0.0060
#   NLPD: -0.3690 ± 0.1295
#   COVERAGE: 0.9730 ± 0.0208

# %%
pbnn_files = [
    'results/pbnn8888/htem_probdense0-dense4_steps200_epochs2000_lr0.005_20241208_213629.pkl'
]

dkl_files = ['results/dkl8888/htem_dkl_comparison_latent2_silu_20241213_180345.pkl']

plot_comparison(
    pbnn_files=pbnn_files,
    dkl_files=dkl_files,
    save_path='comparison_plot-dkl-pbnn8888-silu.png'
);
# Out:
# Final values (mean ± std):
#
# PBNN (0, 4):
#   RMSE: 0.2456 ± 0.0258
#   NLPD: 0.1619 ± 0.0292
#   COVERAGE: 0.9823 ± 0.0101
#
# DKL (latent=2, silu):
#   RMSE: 0.4519 ± 0.0362
#   NLPD: 0.7770 ± 0.0305
#   COVERAGE: 0.9883 ± 0.0087

# %%
pbnn_files = [
    'results/pbnn8888/htem_probdense0-dense4_steps200_epochs2000_lr0.005_20241208_213629.pkl'
]

gp_files = ['results/gp/gp_comparison_kernelmatern52_20241213_183211.pkl']

plot_comparison(
    pbnn_files=pbnn_files,
    gp_files=gp_files,
    save_path='comparison_plot-gp-pbnn8888-silu.png'
);
# Out:
# Final values (mean ± std):
#
# PBNN (0, 4):
#   RMSE: 0.2456 ± 0.0258
#   NLPD: 0.1619 ± 0.0292
#   COVERAGE: 0.9823 ± 0.0101
#
# GP (matern52):
#   RMSE: 0.2421 ± 0.0156
#   NLPD: 0.0085 ± 0.0741
#   COVERAGE: 0.9618 ± 0.0066
